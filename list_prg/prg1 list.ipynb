# %%
print("hello")
# Out:
# hello

# %%
pip install pandas
# Out:
# ...
#                                               0.0/9.9 MB ? eta -:--:--
#                                               0.0/9.9 MB ? eta -:--:--
#                                               0.0/9.9 MB ? eta -:--:--
#                                               0.1/9.9 MB 1.1 MB/s eta 0:00:09
#                                               0.1/9.9 MB 1.1 MB/s eta 0:00:09
#                                               0.2/9.9 MB 1.2 MB/s eta 0:00:09
#                                               0.2/9.9 MB 1.2 MB/s eta 0:00:09
#      --                                       0.5/9.9 MB 1.7 MB/s eta 0:00:06
#      --                                       0.5/9.9 MB 1.7 MB/s eta 0:00:06
#      --                                       0.5/9.9 MB 1.7 MB/s eta 0:00:06
#      ----                                     1.1/9.9 MB 2.6 MB/s eta 0:00:04
#      ----                                     1.1/9.9 MB 2.6 MB/s eta 0:00:04
# ...

# %%
import pandas as pd

# %%
data=pd.read_csv("tip.csv")

# %%
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#list operations

# %%
l1=list()

# %%
type(l1)
# Out:
# list

# %%
l1.append(10)

# %%
l1.append(2)

# %%
l1.append(30)

# %%
l1.append(23)

# %%
l1
# Out:
# [30, 2, 30, 23]

# %%
l1[-2]
# Out:
# 30

# %%
l1.sort()

# %%
l1
# Out:
# [2, 23, 30, 30]

# %%
num=[2,5,10,1,23,21,11]
num.sort()
num
# Out:
# [1, 2, 5, 10, 11, 21, 23]

# %%
nums=sorted(num)

# %%
nums
# Out:
# [1, 2, 5, 10, 11, 21, 23]

# %%
names=['vishnu','Gathi','glori','hail']

# %%
names.sort()
names
# Out:
# ['Gathi', 'glori', 'hail', 'vishnu']

# %%
name= sorted(names)
name
# Out:
# ['Gathi', 'glori', 'hail', 'vishnu']

# %%
#sort names based on len

# %%
lnames=sorted(names,key=len,reverse=True)# rev give thirinj varum

# %%
lnames
# Out:
# ['vishnu', 'Gathi', 'glori', 'hail']

# %%
lnum=[i for  i in range(1,10)]

# %%
lnum
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
lnum=[2**i for i in range(0,9)]
lnum[0]=0

# %%
lnum
# Out:
# [0, 2, 4, 8, 16, 32, 64, 128, 256]

# %%
lnums=[(2*i)-1 for i in range(1,6)]
lnums
# Out:
# [1, 3, 5, 7, 9]

# %%
lm=[2,4,3,2,6,1,8,1]

# %%
m=[]

# %%
for i  in lm:
    if i not in m:
        m.append(i)

# %%
m
# Out:
# [2, 4, 3, 6, 1, 8]

# %%
rm=[2,3,8,4,5]

# %%
length=len(rm)

# %%
d={'a':100,'b':200,'c':300}
d.get('a')
# Out:
# 100

# %%
d.get('d',0)
# Out:
# 0

# %%
d
# Out:
# {'a': 100, 'b': 200, 'c': 300}

# %%
d.popitem()
# Out:
# ('c', 300)

# %%
d.pop('a')
# Out:
# 100

# %%
d
# Out:
# {'b': 200}
