# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None
        self.prev=None

# %%
n1=Node("Gayathri")
n2=Node("Vishnu")
n3=Node("Anushka")

# %%
n1.next=n2
n1.prev=None

# %%
n2.next=n3
n2.prev=n1

# %%
n3.next=None
n3.prev=n2

# %%
cur=n1
while cur:
    print(cur.data)
    cur=cur.next
# Out:
# Gayathri
# Vishnu
# Anushka

# %%
print(n1.next.next.data)
# Out:
# Anushka

# %%
print(n2.prev.next.data)
# Out:
# Vishnu

# %%
#create a node and add at beginning and at end
#at specific location

# %%
n1=Node(500)    #real data
n2=Node(200)
n3=Node(300)
n0=Node(100)

# %%
n1.next=n2
n1.prev=None
n2.next=n3
n2.prev=n1
n3.next=None
n3.prev=n2

# %%
cur=n1
while cur:
    print(cur.data)
    cur=cur.next
# Out:
# 500
# 200
# 300

# %%
n0.next=n1                     #add at the front
n0.prev=None
n1.prev=n0 
cur=n0
while cur:
    print(cur.data)
    cur=cur.next
# Out:
# 100
# 500
# 200
# 300

# %%
n11=Node(400)                      #add at end
n11.next=None
n11.prev=n3
n3.next=n11
cur=n0
while cur:
    print(cur.data)
    cur=cur.next
# Out:
# 100
# 500
# 200
# 300
# 400
